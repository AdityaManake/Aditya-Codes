# %%
import torch

# %%
x = torch.randn(3, requires_grad=True)
x
# Out:
# tensor([1.0438, 0.6930, 0.3999], requires_grad=True)

# %%
y = x + 2
y
# Out:
# tensor([3.0438, 2.6930, 2.3999], grad_fn=<AddBackward0>)

# %%
z = y * y * 2
z
# Out:
# tensor([18.5294, 14.5048, 11.5186], grad_fn=<MulBackward0>)

# %%
z = z.mean()
z
# Out:
# tensor(14.8509, grad_fn=<MeanBackward0>)

# %%
z.backward()
print(x.grad)
# Out:
# tensor([4.0584, 3.5907, 3.1998])
